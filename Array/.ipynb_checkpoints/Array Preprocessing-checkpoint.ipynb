# %% [markdown]
# # Array Preprocessing
#
# # 1. reverse
#
# ## [!189. Rotate Array](https://leetcode.com/problems/rotate-array/)
#
# ```
# Given an array, rotate the array to the right by k steps, where k is non-negative.
#
# Input: nums = [1,2,3,4,5,6,7], k = 3
# Output: [5,6,7,1,2,3,4]
# Explanation:
# rotate 1 steps to the right: [7,1,2,3,4,5,6]
# rotate 2 steps to the right: [6,7,1,2,3,4,5]
# rotate 3 steps to the right: [5,6,7,1,2,3,4]
# ```
#
# ```python
# class Solution:
#     def rotate(self, nums: List[int], k: int) -> None:
#         """
#         Do not return anything, modify nums in-place instead.
#         """
#         k %= len(nums)
#         self.reverse(nums, 0, len(nums)-1)
#         self.reverse(nums, 0, k-1)
#         self.reverse(nums, k, len(nums)-1)
#
#
#     def reverse(self, nums, start, end):
#         while start < end:
#             nums[start], nums[end] = nums[end], nums[start]
#             start += 1
#             end -= 1
# ```
#
# # 2. Sort
#
# # 3. Reshape
#
# 遇到矩阵变换的优先考虑索引的整除 or 地板除。
#
# ```python
# class Solution:
#     def matrixReshape(self, nums: List[List[int]], r: int, c: int) -> List[List[int]]:
#         m = len(nums)
#         n = len(nums[0])
#
#         if m * n != r * c:
#             return nums
#
#         matrix = [[0 for _ in range(c)] for _ in range(r)]
#         for i in range(r * c):
#             matrix[i//c][i%c] = nums[i//n][i%n]
#         return matrix
# ```
#
# # 4.Transpose
#
# Given a matrix A, return the transpose of A.
#
# The transpose of a matrix is the matrix flipped over it's main diagonal, switching the row and column indices of the matrix.
#
#
# ```python
# class Solution:
#     def transpose(self, A: List[List[int]]) -> List[List[int]]:
#         return list(zip(*A))
# ```
#
# <font color='red'>zip的用法：  </font>
# 1. Let's A = [[1, 2, 3], [10, 20, 30]]
# 2. zip is a Python built-in function which accepts one or more iterables (each could be a list, tuple, set, ... or any combination of them). What zip does comes below.
# 3. *A inside zip represents the parameter A as two parameters [1, 2, 3] and [10, 20, 30]. Note that this is the general behaviour of * and it's called unpacking as it unpacks the iterable (A in our example) to its immediate children and makes them available for the current operation (zip in our example)
# 4. Now let's see what zip does in our example: It gets [1, 2, 3] and [10, 20, 30] and returns (1, 10), (2, 20), (3, 30) [Please see note 5]. As you see, it gathers all the first elements (of the children) together and creates a tuple out of them. And then gathers the second elements and creates the second tuple. The same idea applies in general case. As you see this is basically the definition of transpose.
# 5. Important Note: zip (in Python 3) actually does not return the entire result set in one shot. What it actually does is doing it lazily, meaning it returns an iterator which the user can ask to generate step by step (as in for or while loop or assigning it to a variable for a later use). However, you can wrap a function around it to force it to return the whole result in one shot (as in list(zip(...) function, ....).
# 6. Among many things Python 3 behaves differently than Python 2, zip is one of the famous examples:
#     - Returning lazily: zip in Python 3 equals (behaves as) Izip in Python 2
#     - Always returning the entire result as a list in one shot: for how zip behaves in Python 2 there is no equivalent built-in function in Python 3. This means zip(..) in python 2 equals list(zip(...) in Python 3
